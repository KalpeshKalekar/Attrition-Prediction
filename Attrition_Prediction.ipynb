# %%
#filter warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# # Read DataSet

# %%
import pandas as pd
AttritionData = pd.read_csv("F:/Course/Pandas/Csv/Attrition Case Study.csv")

# %%
AttritionData
# Out:
#       Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0             1   41      Travel_Rarely       1102                   Sales
# 1             0   49  Travel_Frequently        279  Research & Development
# 2             1   37      Travel_Rarely       1373  Research & Development
# 3             0   33  Travel_Frequently       1392  Research & Development
# 4             0   27      Travel_Rarely        591  Research & Development
# ...         ...  ...                ...        ...                     ...
# 1465          0   36  Travel_Frequently        884  Research & Development
# 1466          0   39      Travel_Rarely        613  Research & Development
# 1467          0   27      Travel_Rarely        155  Research & Development
# 1468          0   49  Travel_Frequently       1023                   Sales
# 1469          0   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# # Defining Problem Statement

# %% [markdown]
# Create a Predictive model which can tell weather to employee will leave or not?
#
# Target Variable: Attrition
#
# Predictors: Age, BusinessTravel, DailyRate  etc.
#
# Attrition ="1" means left.
#
# Attrition ="0" means not left .

# %% [markdown]
# # Basic Data Exploration

# %% [markdown]
# head() : This helps to see a few sample rows of the data
#
# info() : This provides the summarized information of the data
#
# describe() : This provides the descriptive statistical details of the data
#
# nunique(): This helps us to identify if a column is categorical or continuous

# %%
AttritionData.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
AttritionData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1470 non-null   int64
#  1   Age                       1470 non-null   int64
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
AttritionData.describe()
# Out:
#          Attrition          Age    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean      0.161224    36.923810   802.485714          9.192517     2.912925
# std       0.367863     9.135373   403.509100          8.106864     1.024165
# min       0.000000    18.000000   102.000000          1.000000     1.000000
# 25%       0.000000    30.000000   465.000000          2.000000     2.000000
# 50%       0.000000    36.000000   802.000000          7.000000     3.000000
# 75%       0.000000    43.000000  1157.000000         14.000000     4.000000
# max       1.000000    60.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
AttritionData.nunique()
# Out:
# Attrition                      2
# Age                           43
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# # Dropping Unwanted Column

# %% [raw]
# As EmployeeNumber,EmployeeCount,Over18,StandardHours will not play important role in prediction

# %%
#dropping column
AttritionData = AttritionData.drop(labels=["EmployeeNumber","EmployeeCount","Over18","StandardHours"],axis=1)

# %%
#checking is column is dropped
AttritionData.head()
# Out:
#    Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0          1   41      Travel_Rarely       1102                   Sales
# 1          0   49  Travel_Frequently        279  Research & Development
# 2          1   37      Travel_Rarely       1373  Research & Development
# 3          0   33  Travel_Frequently       1392  Research & Development
# 4          0   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# ...

# %% [markdown]
# # Dropping any duplicates values

# %%
#printing shape of data before dropping duplicates values
print("Shape of Data before dropping duplicates values : ",AttritionData.shape)

#printing shape of data after dropping duplicates values
AttritionData = AttritionData.drop_duplicates()
print("Shape of Data after dropping duplicates values : ",AttritionData.shape)
# Out:
# Shape of Data before dropping duplicates values :  (1470, 31)
# Shape of Data after dropping duplicates values :  (1470, 31)

# %% [markdown]
# Data shows no duplicates values

# %% [markdown]
# # Looking for distribution of target variable

# %%
groupData = AttritionData.groupby("Attrition").size()
groupData.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Attrition'>

# %% [markdown]
# # Visual Data Exploration

# %% [raw]
# Categorical variables: Bar plot
# Continuous variables: Histogram

# %% [markdown]
# # Visualize distribution of all the Categorical Predictor variables in the data using bar plots

# %%
#Seperating continous and categorical columns
cat = []
con = []

for i in AttritionData.columns:
    if (AttritionData[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
con
# Out:
# ['Attrition',
#  'Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
con.remove('PerformanceRating')

# %%
cat.append('PerformanceRating')

# %%
con.remove('Attrition')

# %%
cat.append('Attrition')

# %%
AttritionData
# Out:
#       Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0             1   41      Travel_Rarely       1102                   Sales
# 1             0   49  Travel_Frequently        279  Research & Development
# 2             1   37      Travel_Rarely       1373  Research & Development
# 3             0   33  Travel_Frequently       1392  Research & Development
# 4             0   27      Travel_Rarely        591  Research & Development
# ...         ...  ...                ...        ...                     ...
# 1465          0   36  Travel_Frequently        884  Research & Development
# 1466          0   39      Travel_Rarely        613  Research & Development
# 1467          0   27      Travel_Rarely        155  Research & Development
# 1468          0   49  Travel_Frequently       1023                   Sales
# 1469          0   34      Travel_Rarely        628  Research & Development
#
# ...

# %%
#plotting Bar chart for categorical columns / plotting count plot
import matplotlib.pyplot as plt
import seaborn as sb
from seaborn import countplot
from seaborn import displot

plt.figure(figsize=(40,50))
x = 1
for i in cat:
    plt.subplot(5,2,x)
    countplot(AttritionData[i])
    x = x+1

# %% [markdown]
# # Visualize distribution of all the Continuous Predictor variables in the data using histograms

# %%
AttritionData.hist(con,figsize=(15,18))
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'DailyRate'}>,
#         <AxesSubplot:title={'center':'DistanceFromHome'}>,
#         <AxesSubplot:title={'center':'Education'}>,
#         <AxesSubplot:title={'center':'EnvironmentSatisfaction'}>],
#        [<AxesSubplot:title={'center':'HourlyRate'}>,
#         <AxesSubplot:title={'center':'JobInvolvement'}>,
#         <AxesSubplot:title={'center':'JobLevel'}>,
#         <AxesSubplot:title={'center':'JobSatisfaction'}>,
#         <AxesSubplot:title={'center':'MonthlyIncome'}>],
#        [<AxesSubplot:title={'center':'MonthlyRate'}>,
#         <AxesSubplot:title={'center':'NumCompaniesWorked'}>,
#         <AxesSubplot:title={'center':'PercentSalaryHike'}>,
#         <AxesSubplot:title={'center':'RelationshipSatisfaction'}>,
#         <AxesSubplot:title={'center':'StockOptionLevel'}>],
#        [<AxesSubplot:title={'center':'TotalWorkingYears'}>,
# ...

# %% [markdown]
# # Missing Data treatment

# %%
#checking for missing data
AttritionData.isnull().sum()
# Out:
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %% [markdown]
# No missing data found

# %% [markdown]
# # Visual exploration of relationship between variables

# %% [raw]
# Continuous Vs Continuous ---- Scatter Plot
# Categorical Vs Continuous---- Box Plot
# Categorical Vs Categorical---- Grouped Bar Plots

# %% [markdown]
# # Statistical measurement of relationship strength between variables

# %% [raw]
# Continuous Vs Continuous ---- Correlation matrix
# Categorical Vs Continuous---- ANOVA test
# Categorical Vs Categorical--- Chi-Square test

# %% [raw]
# In this case study the Target variable is Categorical, hence below two scenarios will be present
#
# Categorical Target Variable Vs Continuous Predictor
# Categorical Target Variable Vs Categorical Predictor

# %%
con
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
cat
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime',
#  'PerformanceRating',
#  'Attrition']

# %%
cat.remove('Attrition')

# %%
#plotting boxplot for continous and target variable
plt.figure(figsize=(15,30))
x = 1
for i in con:
    plt.subplot(8,3,x)
    sb.boxplot(AttritionData["Attrition"],AttritionData[i])
    x = x + 1

# %%
def FunctionAnova(inpData,TargetVariable,ContinousPredictors):
    from scipy.stats import f_oneway
    #creating list for selected columns
    SelectedPredictors = []
    for predictors in ContinousPredictors:
        ContinousPredictorsList = inpData.groupby(TargetVariable)[predictors].apply(list)
        AnovaResults = f_oneway(*ContinousPredictorsList)
    #seperating selected columns
        if (AnovaResults[1] < 0.05):
            print("\n",predictors, 'is correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
            SelectedPredictors.append(predictors)
        else:
            print("\n",predictors, 'is NOT correlated with', TargetVariable, '| P-Value:', AnovaResults[1])
    
    return(SelectedPredictors)

# %%
FunctionAnova(inpData=AttritionData,TargetVariable="Attrition",ContinousPredictors=con)
# Out:
#  Age is correlated with Attrition | P-Value: 8.356308021102401e-10
#
#  DailyRate is correlated with Attrition | P-Value: 0.02985816066026101
#
#  DistanceFromHome is correlated with Attrition | P-Value: 0.0027930600802132115
#
#  Education is NOT correlated with Attrition | P-Value: 0.2293152033222874
#
#  EnvironmentSatisfaction is correlated with Attrition | P-Value: 7.172338549367721e-05
#
#  HourlyRate is NOT correlated with Attrition | P-Value: 0.7931347689944519
#
#  JobInvolvement is correlated with Attrition | P-Value: 5.677065356744583e-07
#
#  JobLevel is correlated with Attrition | P-Value: 6.795384780014228e-11
#
#  JobSatisfaction is correlated with Attrition | P-Value: 7.043066741730351e-05
#
#  MonthlyIncome is correlated with Attrition | P-Value: 7.147363985353002e-10
#
#  MonthlyRate is NOT correlated with Attrition | P-Value: 0.5611235982243229
#
#  NumCompaniesWorked is NOT correlated with Attrition | P-Value: 0.09552526205649159
#
# ...

# %%
#plotting groupbarchart for categorical and target variable
plt.figure(figsize=(40,50))
x = 1
for i in cat:
    plt.subplot(4,2,x)
    countplot(AttritionData[i],hue=AttritionData["Attrition"])
    x = x + 1

# %%
def FunctionChisq(inpData, TargetVariable, CategoricalVariablesList):
    from scipy.stats import chi2_contingency
    
    # Creating an empty list of final selected predictors
    SelectedPredictors=[]

    for predictor in CategoricalVariablesList:
        CrossTabResult=pd.crosstab(index=inpData[TargetVariable], columns=inpData[predictor])
        ChiSqResult = chi2_contingency(CrossTabResult)
        
        # If the ChiSq P-Value is <0.05, that means we reject H0
        if (ChiSqResult[1] < 0.05):
            print("\n",predictor, 'is correlated with', TargetVariable, '| P-Value:', ChiSqResult[1])
            SelectedPredictors.append(predictor)
        else:
            print("\n",predictor, 'is NOT correlated with', TargetVariable, '| P-Value:', ChiSqResult[1])        
            
    return(SelectedPredictors)

# %%
FunctionChisq(inpData=AttritionData,TargetVariable="Attrition",CategoricalVariablesList=cat)
# Out:
#  BusinessTravel is correlated with Attrition | P-Value: 5.608614476449931e-06
#
#  Department is correlated with Attrition | P-Value: 0.004525606574479633
#
#  EducationField is correlated with Attrition | P-Value: 0.006773980139025222
#
#  Gender is NOT correlated with Attrition | P-Value: 0.29057244902890855
#
#  JobRole is correlated with Attrition | P-Value: 2.752481638050657e-15
#
#  MaritalStatus is correlated with Attrition | P-Value: 9.45551106034083e-11
#
#  OverTime is correlated with Attrition | P-Value: 8.15842372153832e-21
#
#  PerformanceRating is NOT correlated with Attrition | P-Value: 0.9900745465934576
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %% [markdown]
# # Defining Predictors and Target Variable

# %%
AttritionData.columns
# Out:
# Index(['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
Y = AttritionData["Attrition"]

# %%
X = AttritionData.drop(labels=['Attrition','Education','Gender','HourlyRate','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','YearsSinceLastPromotion'],axis=1)

# %%
Y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
X
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome EducationField  EnvironmentSatisfaction  \
# 0                    1  Life Sciences                        2
# 1                    8  Life Sciences                        3
# ...

# %% [markdown]
# # Standardization of Data

# %%
#Seperating continous and categorical columns
cat = []
con = []

for i in X.columns:
    if (X[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X1 = pd.DataFrame(ss.fit_transform(X[con]),columns=con)
X2 = pd.get_dummies(X[cat])
Xnew = X1.join(X2)

# %%
Xnew
# Out:
#            Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# 0     0.446350   0.742527         -1.010909                -0.660531
# 1     1.322365  -1.297775         -0.147150                 0.254625
# 2     0.008343   1.414363         -0.887515                 1.169781
# 3    -0.429664   1.461466         -0.764121                 1.169781
# 4    -1.086676  -0.524295         -0.887515                -1.575686
# ...        ...        ...               ...                      ...
# 1465 -0.101159   0.202082          1.703764                 0.254625
# 1466  0.227347  -0.469754         -0.393938                 1.169781
# 1467 -1.086676  -1.605183         -0.640727                -0.660531
# 1468  1.322365   0.546677         -0.887515                 1.169781
# 1469 -0.320163  -0.432568         -0.147150                -0.660531
#
#       JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0           0.379672 -0.057788         1.153254      -0.108350
# ...

# %% [markdown]
# # Splitting Data into Training and Testing

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(Xnew,Y,random_state=42,test_size=0.3)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lrModel = lr.fit(xtrain,ytrain)
#prediction on test data
prediction = lrModel.predict(xtest)

from sklearn.metrics import classification_report,confusion_matrix,f1_score
print(classification_report(ytest,prediction))
print(confusion_matrix(ytest,prediction))

F1_score = f1_score(ytest,prediction,average="weighted")
print("Accuracy on testing sample data : ",round(F1_score,2))

from sklearn.model_selection import cross_val_score
Accuracy_values = cross_val_score(lrModel,Xnew,Y,cv=10,scoring="f1_weighted")
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_values.mean(),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       380
#            1       0.65      0.39      0.49        61
#
#     accuracy                           0.89       441
#    macro avg       0.78      0.68      0.71       441
# weighted avg       0.87      0.89      0.87       441
#
# [[367  13]
#  [ 37  24]]
# Accuracy on testing sample data :  0.87
#
# Accuracy values for 10-fold Cross Validation:
#  [0.87896079 0.84508704 0.87554712 0.84998818 0.84998818 0.80751685
#  0.82887729 0.87269193 0.86445501 0.89622494]
#
# Final Average Accuracy of the model: 0.86

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

from sklearn.model_selection import GridSearchCV
tg = {"max_depth": range(1,15,1),"criterion":["gini","entropy"]}
cv = GridSearchCV(dtc,tg,scoring="accuracy",cv=4)
cvModel = cv.fit(Xnew,Y)

# %%
cvModel.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 5}

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(max_depth=5,criterion="gini")
dtcModel = dtc.fit(xtrain,ytrain)
#prediction on testing data
prediction = dtcModel.predict(xtest)

from sklearn.metrics import classification_report,confusion_matrix,f1_score
print(classification_report(ytest,prediction))
print(confusion_matrix(ytest,prediction))

F1_score = f1_score(ytest,prediction,average="weighted")
print("Accuracy on testing sample data : ",round(F1_score,2))

from sklearn.model_selection import cross_val_score
Accuracy_values = cross_val_score(dtcModel,Xnew,Y,cv=10,scoring="f1_weighted")
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_values.mean(),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92       380
#            1       0.53      0.33      0.40        61
#
#     accuracy                           0.87       441
#    macro avg       0.71      0.64      0.66       441
# weighted avg       0.85      0.87      0.85       441
#
# [[362  18]
#  [ 41  20]]
# Accuracy on testing sample data :  0.85
#
# Accuracy values for 10-fold Cross Validation:
#  [0.83234535 0.81330994 0.80261603 0.80829118 0.84143181 0.82355712
#  0.82297927 0.8166156  0.83781872 0.84088328]
#
# Final Average Accuracy of the model: 0.82

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

from sklearn.model_selection import GridSearchCV
tg = {"max_depth": range(1,15,1),"criterion":["gini","entropy"],"n_estimators":range(10,200,10)}
cv = GridSearchCV(rfc,tg,scoring="accuracy",cv=4)
cvModel = cv.fit(Xnew,Y)

# %%
cvModel.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 13, 'n_estimators': 100}

# %%
rfc = RandomForestClassifier(max_depth=13,criterion="entropy",n_estimators = 100)
rfcModel = rfc.fit(xtrain,ytrain)
#prediction on testing data
prediction = rfcModel.predict(xtest)

from sklearn.metrics import classification_report,confusion_matrix,f1_score
print(classification_report(ytest,prediction))
print(confusion_matrix(ytest,prediction))

F1_score = f1_score(ytest,prediction,average="weighted")
print("Accuracy on testing sample data : ",round(F1_score,2))

from sklearn.model_selection import cross_val_score
Accuracy_values = cross_val_score(rfcModel,Xnew,Y,cv=10,scoring="f1_weighted")
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_values.mean(),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       380
#            1       0.64      0.15      0.24        61
#
#     accuracy                           0.87       441
#    macro avg       0.76      0.57      0.58       441
# weighted avg       0.85      0.87      0.83       441
#
# [[375   5]
#  [ 52   9]]
# Accuracy on testing sample data :  0.83
#
# Accuracy values for 10-fold Cross Validation:
#  [0.81546612 0.82046954 0.84998818 0.85067768 0.85563764 0.81749494
#  0.82258941 0.84860853 0.84233543 0.86445501]
#
# Final Average Accuracy of the model: 0.84

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
dtc = DecisionTreeClassifier(max_depth=5)
abModel = AdaBoostClassifier(base_estimator=dtc)

from sklearn.model_selection import GridSearchCV
tg = {"n_estimators":range(10,200,10)}
cv = GridSearchCV(abModel,tg,scoring="accuracy",cv=4)
cvModel = cv.fit(Xnew,Y)

# %%
cvModel.best_params_
# Out:
# {'n_estimators': 180}

# %%
from sklearn.ensemble import AdaBoostClassifier
dtc = DecisionTreeClassifier(max_depth=5)
abModel = AdaBoostClassifier(base_estimator=dtc,n_estimators=180,learning_rate=0.01)

abModel = abModel.fit(xtrain,ytrain)
#prediction on testing data
prediction = abModel.predict(xtest)

from sklearn.metrics import classification_report,confusion_matrix,f1_score
print(classification_report(ytest,prediction))
print(confusion_matrix(ytest,prediction))

F1_score = f1_score(ytest,prediction,average="weighted")
print("Accuracy on testing sample data : ",round(F1_score,2))

from sklearn.model_selection import cross_val_score
Accuracy_values = cross_val_score(abModel,Xnew,Y,cv=10,scoring="f1_weighted")
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_values.mean(),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       380
#            1       0.81      0.21      0.34        61
#
#     accuracy                           0.88       441
#    macro avg       0.85      0.60      0.64       441
# weighted avg       0.88      0.88      0.85       441
#
# [[377   3]
#  [ 48  13]]
# Accuracy on testing sample data :  0.85
#
# Accuracy values for 10-fold Cross Validation:
#  [0.82046954 0.83304078 0.84508704 0.83408631 0.8444339  0.83419746
#  0.82887729 0.83178726 0.77226229 0.81014542]
#
# Final Average Accuracy of the model: 0.83

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()

from sklearn.model_selection import GridSearchCV
tg = {"n_neighbors":range(2,6,1)}
cv = GridSearchCV(knn,tg,scoring="accuracy",cv=4)
cvModel = cv.fit(Xnew,Y)

# %%
cvModel.best_params_
# Out:
# {'n_neighbors': 5}

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

knnModel = knn.fit(xtrain,ytrain)
#prediction on testing data
prediction = knnModel.predict(xtest)

from sklearn.metrics import classification_report,confusion_matrix,f1_score
print(classification_report(ytest,prediction))
print(confusion_matrix(ytest,prediction))

F1_score = f1_score(ytest,prediction,average="weighted")
print("Accuracy on testing sample data : ",round(F1_score,2))

from sklearn.model_selection import cross_val_score
Accuracy_values = cross_val_score(knnModel,Xnew,Y,cv=10,scoring="f1_weighted")
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_values.mean(),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       380
#            1       0.67      0.20      0.30        61
#
#     accuracy                           0.88       441
#    macro avg       0.78      0.59      0.62       441
# weighted avg       0.85      0.88      0.84       441
#
# [[374   6]
#  [ 49  12]]
# Accuracy on testing sample data :  0.84
#
# Accuracy values for 10-fold Cross Validation:
#  [0.7843122  0.79316526 0.83304078 0.78031681 0.79789147 0.76772083
#  0.79789147 0.81985315 0.81014542 0.80729886]
#
# Final Average Accuracy of the model: 0.8

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

nbModel = nb.fit(xtrain,ytrain)
#prediction on testing data
prediction = knnModel.predict(xtest)

from sklearn.metrics import classification_report,confusion_matrix,f1_score
print(classification_report(ytest,prediction))
print(confusion_matrix(ytest,prediction))

F1_score = f1_score(ytest,prediction,average="weighted")
print("Accuracy on testing sample data : ",round(F1_score,2))

from sklearn.model_selection import cross_val_score
Accuracy_values = cross_val_score(nbModel,Xnew,Y,cv=10,scoring="f1_weighted")
print('\nAccuracy values for 10-fold Cross Validation:\n',Accuracy_values)
print('\nFinal Average Accuracy of the model:', round(Accuracy_values.mean(),2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       380
#            1       0.67      0.20      0.30        61
#
#     accuracy                           0.88       441
#    macro avg       0.78      0.59      0.62       441
# weighted avg       0.85      0.88      0.84       441
#
# [[374   6]
#  [ 49  12]]
# Accuracy on testing sample data :  0.84
#
# Accuracy values for 10-fold Cross Validation:
#  [0.72194451 0.75853404 0.76762089 0.70394016 0.7310688  0.71153788
#  0.70359572 0.7343214  0.75793728 0.68863953]
#
# Final Average Accuracy of the model: 0.73

# %% [raw]
# Selecting Random Forest as Final model for prediction

# %% [markdown]
# # Preparing Test Data

# %%
test = pd.read_csv("F:/Course/Pandas/Csv/Attrition Case Study.csv")

# %%
test
# Out:
#       Attrition  Age     BusinessTravel  DailyRate              Department  \
# 0             1   41      Travel_Rarely       1102                   Sales
# 1             0   49  Travel_Frequently        279  Research & Development
# 2             1   37      Travel_Rarely       1373  Research & Development
# 3             0   33  Travel_Frequently       1392  Research & Development
# 4             0   27      Travel_Rarely        591  Research & Development
# ...         ...  ...                ...        ...                     ...
# 1465          0   36  Travel_Frequently        884  Research & Development
# 1466          0   39      Travel_Rarely        613  Research & Development
# 1467          0   27      Travel_Rarely        155  Research & Development
# 1468          0   49  Travel_Frequently       1023                   Sales
# 1469          0   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
test1 = test.drop(labels=['Attrition','Education','Gender','HourlyRate','MonthlyRate','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','YearsSinceLastPromotion',"EmployeeNumber","EmployeeCount","Over18","StandardHours"],axis=1)

# %%
#Seperating continous and categorical columns
cat = []
con = []

for i in test1.columns:
    if (test1[i].dtypes == "object"):
        cat.append(i)
    else:
        con.append(i)

# %%
cat
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'JobRole',
#  'MaritalStatus',
#  'OverTime']

# %%
con
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'EnvironmentSatisfaction',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsWithCurrManager']

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
test2 = pd.DataFrame(ss.fit_transform(test1[con]),columns=con)
test3 = pd.get_dummies(test1[cat])
testnew = test2.join(test3)

# %%
testnew
# Out:
#            Age  DailyRate  DistanceFromHome  EnvironmentSatisfaction  \
# 0     0.446350   0.742527         -1.010909                -0.660531
# 1     1.322365  -1.297775         -0.147150                 0.254625
# 2     0.008343   1.414363         -0.887515                 1.169781
# 3    -0.429664   1.461466         -0.764121                 1.169781
# 4    -1.086676  -0.524295         -0.887515                -1.575686
# ...        ...        ...               ...                      ...
# 1465 -0.101159   0.202082          1.703764                 0.254625
# 1466  0.227347  -0.469754         -0.393938                 1.169781
# 1467 -1.086676  -1.605183         -0.640727                -0.660531
# 1468  1.322365   0.546677         -0.887515                 1.169781
# 1469 -0.320163  -0.432568         -0.147150                -0.660531
#
#       JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0           0.379672 -0.057788         1.153254      -0.108350
# ...

# %%
pred_test = rfcModel.predict(testnew)

# %%
T = test[["EmployeeNumber"]]
T["Attrition"] = pred_test

# %%
T
# Out:
#       EmployeeNumber  Attrition
# 0                  1          1
# 1                  2          0
# 2                  4          1
# 3                  5          0
# 4                  7          0
# ...              ...        ...
# 1465            2061          0
# 1466            2062          0
# 1467            2064          0
# 1468            2065          0
# 1469            2068          0
#
# [1470 rows x 2 columns]

# %%
T.to_csv("Desktop/Attrition_Prediction.csv")
